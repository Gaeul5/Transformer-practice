# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaeul5/Transformer-practice/blob/main/transformer_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 레포지토리 복제
# !git clone https://github.com/Gaeul5/Transformer-practice.git
# %cd Transformer-practice
# Out:
# Cloning into 'Transformer-practice'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 75 (delta 16), reused 24 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 1.19 MiB | 4.81 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/Transformer-practice/Transformer-practice

# %%
# 1. 레포지토리 폴더 안으로 이동
# %cd /content/Transformer-practice

# 2. 이동한 위치에서 파일 실행
# !python train.py
# Out:
# /content/Transformer-practice
# /usr/local/lib/python3.12/dist-packages/torchtext/data/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.12/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.12/dist-packages/torchtext/utils.py:4: UserWarning:
# ...
